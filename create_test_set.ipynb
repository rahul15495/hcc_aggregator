# %%
import pandas as pd
import os 
import random

# %%
diag_f= "test-data/RAJ_DIAG_cleaned.psv"
person_f= "test-data/RAJ_PERSON_cleaned.psv"

#Loading Data Frames and renaming columns
df_diag= pd.read_csv(diag_f, sep='|',names=['Patient_ID', ' ICD10', 'month', 'year'])

df_person= pd.read_csv(person_f, sep='|')
df_person.columns= ['Month_of_eligibility', 'Patient_DOB', 'Gender','Patient_ID', 'RAF_Type']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-694a642cb8e7> in <module>()
#       3
#       4 #Loading Data Frames and renaming columns
# ----> 5 df_diag= pd.read_csv(diag_f, sep='|',names=['Patient_ID', ' ICD10', 'month', 'year'])
#       6
#       7 df_person= pd.read_csv(person_f, sep='|')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'test-data/RAJ_DIAG_cleaned.psv' does not exist

# %%
print('selecting random row from the person df')
#print(df_person.index)
id=random.randint(df_person.index[0],df_person.index[-1] )
temp_patient= dict(df_person.loc[id])
temp_df_person= df_person[df_person.index==id]
# Out:
# selecting random row from the person df

# %%
print("getting diagnosis data for {}: {}".format('Patient_ID', temp_patient['Patient_ID'] ))
temp_diag= df_diag.query("Patient_ID=='{}'".format(temp_patient['Patient_ID']))
temp_diag
# Out:
# getting diagnosis data for Patient_ID: 1132385403999
#            Patient_ID  ICD10  month  year
# 389231  1132385403999   C760      9    17
# 442417  1132385403999   C760     10    17
# 442418  1132385403999   I270     10    17
# 498109  1132385403999   C760     11    17
# 498110  1132385403999   I270     11    17

# %%
temp_diag.to_csv('health_fidelity_hcc/test_data/diag.csv', index= False)

# %%
temp_df_person.to_csv('health_fidelity_hcc/test_data/person.csv', index= False)

# %%
person_test= pd.read_csv('health_fidelity_hcc/test_data/person.csv')
diag_test= pd.read_csv('health_fidelity_hcc/test_data/diag.csv')
# Out:
#       Patient_ID  ICD10  month  year
# 0  1132385403999   C760      9    17
# 1  1132385403999   C760     10    17
# 2  1132385403999   I270     10    17
# 3  1132385403999   C760     11    17
# 4  1132385403999   I270     11    17

# %%
for i in range(100):
    
    print('selecting random row from the person df')
    #print(df_person.index)
    id=random.randint(df_person.index[0],df_person.index[-1] )
    temp_patient= dict(df_person.loc[id])
    temp_df_person= df_person[df_person.index==id]
    
    print("getting diagnosis data for {}: {}".format('Patient_ID', temp_patient['Patient_ID'] ))
    temp_diag= df_diag.query("Patient_ID=='{}'".format(temp_patient['Patient_ID']))
    
    person_test= pd.concat([person_test, temp_df_person], ignore_index=True)
    diag_test= pd.concat([diag_test, temp_diag], ignore_index=True)
# Out:
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1904330415999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1848062742999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1216264346999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 100231512200308033401999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1861174075999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1131158875999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1129608731999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1286942653999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1286961682999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1117046587999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1132685467999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 111540374500999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1962293703999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1132597307999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1957444888999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1118780379999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1130554331999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1918179168999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1133568251999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 100231512163512242801999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 100231512203413142301999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1286939515999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1111751259999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1130359387999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1972353805999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1127283259999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 149192858999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1454733213999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1114643483999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1977277133999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1145069406999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1113845083999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1132981819999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1286958505999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 1131250715999
# selecting random row from the person df
# getting diagnosis data for Patient_ID: 
# 2121  1905398563999    M069      4    17
# 2122  1905398563999    J449      5    17
# 2123  1905398563999  J84111      5    17
# 2124  1905398563999    M059      5    17
# 2125  1905398563999    J449      6    17
# 2126  1905398563999  J84111      6    17
# 2127  1905398563999    M059      6    17
# 2128  1905398563999    J449      7    17
# 2129  1905398563999  J84111      7    17
# 2130  1905398563999    M059      7    17
# 2131  1905398563999    J449      8    17
# 2132  1905398563999  J84111      8    17
# 2133  1905398563999    M059      8    17
# 2134  1905398563999    J432      9    17
# 2135  1905398563999  J84111      9    17
# 2136  1905398563999    M059      9    17
# 2137  1905398563999    J432     10    17
# 2138  1905398563999  J84111     10    17
# 2139  1905398563999    M059     10    17
# 2140  1905398563999    J432     11    17
# 2141  1905398563999  J84111     11    17
# 2142  1905398563999    M059     11    17
# 2143  1905398563999    J432     12    17
# 2144  1905398563999  J84111     12    17
# 2145  1905398563999    M059     12    17
# 2146  1905398563999    M059      3    18
# 2147  1905398563999    M059      4    18
# 2148  1905398563999    M059      5    18
# 2149  1905398563999    M059      6    18
#
# [2150 rows x 4 columns]

# %%
diag_test.to_csv('health_fidelity_hcc/test_data/diag.csv', index= False)

# %%
person_test.to_csv('health_fidelity_hcc/test_data/person.csv', index= False)

# %%
output_f= "test-data/RAJ_OUTPUT_cleaned.psv"

# %%
df_output= pd.read_csv(output_f, sep='|', names= ['Run_date', 'year_of_eligibility', 'Patient_ID', 'DOB','Deceased_date',
                                                 'Gender', 'Group_code', 'Plan_type', 'Observation', 'RAF coefficient',
                                                 'RAF_type'])
# Out:
# /home/user/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_output.head()
# Out:
#      Run_date year_of_eligibility                Patient_ID         DOB  \
# 0  2018-09-24          2017-01-01  100231500030801040901999  1926-07-09
# 1  2018-09-24          2017-02-01  100231500030801040901999  1926-07-09
# 2  2018-09-24          2017-03-01  100231500030801040901999  1926-07-09
# 3  2018-09-24          2017-04-01  100231500030801040901999  1926-07-09
# 4  2018-09-24          2017-05-01  100231500030801040901999  1926-07-09
#
#    Deceased_date Gender Group_code           Plan_type Observation  \
# 0            NaN      F   US354055  MEDICARE ADVANTAGE  CNA_F90_94
# 1            NaN      F   US354055  MEDICARE ADVANTAGE  CNA_F90_94
# 2            NaN      F   US354055  MEDICARE ADVANTAGE  CNA_F90_94
# 3            NaN      F   US354055  MEDICARE ADVANTAGE  CNA_F90_94
# 4            NaN      F   US354055  MEDICARE ADVANTAGE  CNA_F90_94
#
#    RAF coefficient RAF_type
# 0            0.797      CNA
# 1            0.797      CNA
# 2            0.797      CNA
# 3            0.797      CNA
# 4            0.797      CNA

# %%
#df_output=df_output.drop(['Deceased_date'], axis=1)
#df_output['Patient_ID']= df_output['Patient_ID'].astype(str)

# %%
#test_out= pd.DataFrame()
for id in list(person_test.Patient_ID):
    print("extracing Patient_ID=='{}'".format(id))
    temp_output= df_output.query("Patient_ID=={}".format(id))
    test_out= pd.concat([test_out, temp_output], ignore_index=True)
aN      F   AE430044  MEDICARE ADVANTAGE  CNA_F90_94
# 17              NaN      F   AE430044  MEDICARE ADVANTAGE  CNA_F90_94
# 18              NaN      F   AE354635  MEDICARE ADVANTAGE  CNA_F75_79
# 19              NaN      F   AE354635  MEDICARE ADVANTAGE  CNA_F75_79
# 20              NaN      F   AE354635  MEDICARE ADVANTAGE  CNA_F75_79
# 21              NaN      F   AE354635  MEDICARE ADVANTAGE  CNA_F75_79
# 22              NaN      F   AE354635  MEDICARE ADVANTAGE  CNA_F75_79
# 23              NaN      F   AE354635  MEDICARE ADVANTAGE  CNA_F75_79
# 24              NaN      F   AE354635  MEDICARE ADVANTAGE  CNA_F75_79
# 25              NaN      F   AE354635  MEDICARE ADVANTAGE  CNA_F75_79
# 26              NaN      F   AE354635  MEDICARE ADVANTAGE  CNA_F75_79
# 27              NaN      F   AE354635  MEDICARE ADVANTAGE  CNA_F75_79
# 28              NaN      F   AE354635  MEDICARE ADVANTAGE  CNA_F75_79
# 29              NaN      F   AE354635  MEDICARE ADVANTAGE  CNA_F75_79
# ...             ...    ...        ...                 ...         ...
# 2703            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F65_69
# 2704            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F65_69
# 2705            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F65_69
# 2706            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F65_69
# 2707            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F65_69
# 2708            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F65_69
# 2709            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F65_69
# 2710            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F65_69
# 2711            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F65_69
# 2712            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F65_69
# 2713            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F65_69
# 2714            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F65_69
# 2715            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F70_74
# 2716            NaN      F      66070  MEDICARE ADVANTAGE   CNA_HCC40
# 2717            NaN      F      66070  MEDICARE ADVANTAGE  CNA_HCC111
# 2718            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F70_74
# 2719            NaN      F      66070  MEDICARE ADVANTAGE   CNA_HCC40
# 2720            NaN      F      66070  MEDICARE ADVANTAGE  CNA_HCC111
# 2721            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F70_74
# 2722            NaN      F      66070  MEDICARE ADVANTAGE   CNA_HCC40
# 2723            NaN      F      66070  MEDICARE ADVANTAGE  CNA_HCC111
# 2724            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F70_74
# 2725            NaN      F      66070  MEDICARE ADVANTAGE   CNA_HCC40
# 2726            NaN      F      66070  MEDICARE ADVANTAGE  CNA_HCC111
# 2727            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F70_74
# 2728            NaN      F      66070  MEDICARE ADVANTAGE   CNA_HCC40
# 2729            NaN      F      66070  MEDICARE ADVANTAGE  CNA_HCC111
# 2730            NaN      F      66070  MEDICARE ADVANTAGE  CNA_F70_74
# 2731            NaN      F      66070  MEDICARE ADVANTAGE   CNA_HCC40
# 2732            NaN      F      66070  MEDICARE ADVANTAGE  CNA_HCC111
#
#       RAF coefficient RAF_type
# 0               0.664      CNA
# 1               0.664      CNA
# 2               0.664      CNA
# 3               0.664      CNA
# 4               0.664      CNA
# 5               0.664      CNA
# 6               0.664      CNA
# 7               0.664      CNA
# 8               0.664      CNA
# 9               0.664      CNA
# 10              0.664      CNA
# 11              0.664      CNA
# 12              0.797      CNA
# 13              0.797      CNA
# 14              0.797      CNA
# 15              0.797      CNA
# 16              0.797      CNA
# 17              0.797      CNA
# 18              0.448      CNA
# 19              0.448      CNA
# 20              0.448      CNA
# 21              0.448      CNA
# 22              0.448      CNA
# 23              0.448      CNA
# 24              0.448      CNA
# 25              0.448      CNA
# 26              0.448      CNA
# 27              0.448      CNA
# 28              0.448      CNA
# 29              0.448      CNA
# ...               ...      ...
# 2703            0.312      CNA
# 2704            0.312      CNA
# 2705            0.312      CNA
# 2706            0.312      CNA
# 2707            0.312      CNA
# 2708            0.312      CNA
# 2709            0.312      CNA
# 2710            0.312      CNA
# 2711            0.312      CNA
# 2712            0.312      CNA
# 2713            0.312      CNA
# 2714            0.312      CNA
# 2715            0.374      CNA
# 2716            0.423      CNA
# 2717            0.328      CNA
# 2718            0.374      CNA
# 2719            0.423      CNA
# 2720            0.328      CNA
# 2721            0.374      CNA
# 2722            0.423      CNA
# 2723            0.328      CNA
# 2724            0.374      CNA
# 2725            0.423      CNA
# 2726            0.328      CNA
# 2727            0.374      CNA
# 2728            0.423      CNA
# 2729            0.328      CNA
# 2730            0.374      CNA
# 2731            0.423      CNA
# 2732            0.328      CNA
#
# [2733 rows x 11 columns]

# %%
test_out['Group_code'].astype(str)
# Out:
# 0       AE430044
# 1       AE430044
# 2       AE430044
# 3       AE430044
# 4       AE430044
# 5       AE430044
# 6       AE430044
# 7       AE430044
# 8       AE430044
# 9       AE430044
# 10      AE430044
# 11      AE430044
# 12      AE430044
# 13      AE430044
# 14      AE430044
# 15      AE430044
# 16      AE430044
# 17      AE430044
# 18      AE354635
# 19      AE354635
# 20      AE354635
# 21      AE354635
# 22      AE354635
# 23      AE354635
# 24      AE354635
# 25      AE354635
# 26      AE354635
# 27      AE354635
# 28      AE354635
# 29      AE354635
#           ...
# 2703       66070
# 2704       66070
# 2705       66070
# 2706       66070
# 2707       66070
# 2708       66070
# 2709       66070
# 2710       66070
# 2711       66070
# 2712       66070
# 2713       66070
# 2714       66070
# 2715       66070
# 2716       66070
# 2717       66070
# 2718       66070
# 2719       66070
# 2720       66070
# 2721       66070
# 2722       66070
# 2723       66070
# 2724       66070
# 2725       66070
# 2726       66070
# 2727       66070
# 2728       66070
# 2729       66070
# 2730       66070
# 2731       66070
# 2732       66070
# Name: Group_code, Length: 2733, dtype: object

# %%
test_out=test_out.drop(['Deceased_date'], axis=1)

# %%
test_out.head()
# Out:
#      Run_date year_of_eligibility                Patient_ID         DOB  \
# 0  2018-09-24          2017-01-01  100231512200308033401999  1927-11-08
# 1  2018-09-24          2017-02-01  100231512200308033401999  1927-11-08
# 2  2018-09-24          2017-03-01  100231512200308033401999  1927-11-08
# 3  2018-09-24          2017-04-01  100231512200308033401999  1927-11-08
# 4  2018-09-24          2017-05-01  100231512200308033401999  1927-11-08
#
#   Gender Group_code           Plan_type Observation  RAF coefficient RAF_type
# 0      F   AE430044  MEDICARE ADVANTAGE  CNA_F85_89            0.664      CNA
# 1      F   AE430044  MEDICARE ADVANTAGE  CNA_F85_89            0.664      CNA
# 2      F   AE430044  MEDICARE ADVANTAGE  CNA_F85_89            0.664      CNA
# 3      F   AE430044  MEDICARE ADVANTAGE  CNA_F85_89            0.664      CNA
# 4      F   AE430044  MEDICARE ADVANTAGE  CNA_F85_89            0.664      CNA

# %%
test_out.to_csv('health_fidelity_hcc/test_data/output.csv', index= False)

# %%
test_out['RAF coefficient']= test_out['RAF coefficient'].astype(float)

# %%
test_out['RAF coefficient']=pd.to_numeric(test_out['RAF coefficient'], downcast='float')

# %%
len(test)
